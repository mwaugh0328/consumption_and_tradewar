# %% [markdown]
# ## Main Driver file for ["The Consumption Response to Trade Shocks: Evidence from the US-China Trade War"](http://www.waugheconomics.com/uploads/2/2/5/6/22563786/waugh_consumption.pdf)
#
# This file will run all the notebooks from data construciton to regression results and generation of figures.
#
# **TODO: Add in data construction files and mapping files**

# %% [markdown]
# **Table of Contents** with hyperlinks
#
# - [Data Construction](#data)
# - [Summary Statistics and Auto Results](#sum_stats)
# - [Export Results](#trade_stats)
# - [Employment Results](#emp_stats)
# - [Pretrend Autos](#pretrend_autos)
# - [Pretrend Employment](#pretrend_emp)
# - [Mapping](#mapping)
#
# None of these files depend upon each other. Just run the code cell below to activate the varible below. Also the auto results will not run as the data is not posted. Summary stats can be replicated via the employment notebook.

# %% [markdown]
# ## Data Construction
# <a id='data'></a>

# %% [markdown]
# ### 1. Construct Tariff Series

# %%
# %run updated_tariff_data.ipynb

# %% [markdown]
# ### 2. Construct Concordance

# %%
# %run alt_hs_naics_mapping.ipynb

# %% [markdown]
# ### 3. Construct County-Level Tariffs and Exports

# %%
# %run countylevel_tariffs_and_exports.ipynb
# Out:
# **********************************************************************************
# ...
#
# Type of zipfile object: <class 'zipfile.ZipFile'>
#
# **********************************************************************************
# ...
# **********************************************************************************
# Constructing County-Level Tariffs and Exports

# %% [markdown]
# ### 4. Construct County-Level by Time Employment Statistics
#
# **TODO** update path variables so it correctly writes and pulls stuff from the correct places. Rightnow has sanbox stuff.

# %%
# %run bls_single_file.ipynb
# Out:
# **********************************************************************************
# ...
#
#
# **********************************************************************************
# ...
#
#
# **********************************************************************************
# ...
#
#
# **********************************************************************************
# ...
#
#
# **********************************************************************************
# Constructing Employment Series

# %% [markdown]
# ---
#
# ## Summary Statistics, Simple Auto Results, Auto Regressions:
# ### Table 1 thourgh Table 3, Figure 1 and Figure 2
#
# Not again, the auto notebook is not posted, but (i) summary stats can be replicated in the employment or trade notebooks and (ii) the pushed notebook will preserve the output to be seen.
# <a id='sum_stats'></a>

# %%
driver_flag = True

# %%
# %run auto_trade_analysis.ipynb

# %% [markdown]
# ---
# ## Trade Results: Table 4
# <a id='trade_stats'></a>

# %%
# %run trade_analysis.ipynb
# Out:
# **********************************************************************************
# Raw Regression Total Trade Growth on Tariff Change
#
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     total_trade_growth   R-squared:                        0.1076
# Estimator:                   PanelOLS   R-squared (Between):             -0.0191
# No. Observations:               51552   R-squared (Within):               0.1964
# Date:                Tue, Dec 17 2019   R-squared (Overall):              0.1076
# Time:                        08:24:21   Log-likelihood                 4.972e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                   1.337e+04
# Entities:                        2864   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                 F(1,51550)
# Min Obs:                       18.000
# ...

# %% [markdown]
# ---
# ## Employment Results: Table 5 and Table 6
#
# ### Total Employment Results
# <a id='emp_stats'></a>

# %%
emp_measure = "emp_all"

# %run employment_analysis.ipynb
# Out:
# **********************************************************************************
# Raw Regression Employment Growth on Tariffs
#
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:      employment_growth   R-squared:                        0.0053
# Estimator:                   PanelOLS   R-squared (Between):              0.0054
# No. Observations:               56199   R-squared (Within):               0.0052
# Date:                Tue, Dec 17 2019   R-squared (Overall):              0.0053
# Time:                        08:24:45   Log-likelihood                 1.299e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                   2.073e+04
# Entities:                        3128   P-value                           0.0000
# Avg Obs:                       17.966   Distribution:                 F(1,56197)
# Min Obs:                       3.0000
# ...

# %% [markdown]
# ---
#
# ### Goods-Producing Employment Results

# %%
emp_measure = "emp_gds"

# %run employment_analysis.ipynb
# Out:
# **********************************************************************************
# Raw Regression Employment Growth on Tariffs
#
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:      employment_growth   R-squared:                        0.0036
# Estimator:                   PanelOLS   R-squared (Between):              0.0052
# No. Observations:               55797   R-squared (Within):               0.0017
# Date:                Tue, Dec 17 2019   R-squared (Overall):              0.0036
# Time:                        08:26:43   Log-likelihood                 8.464e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      8083.4
# Entities:                        3120   P-value                           0.0000
# Avg Obs:                       17.884   Distribution:                 F(1,55795)
# Min Obs:                       3.0000
# ...

# %% [markdown]
# ---
#
# ### Retail Employment Results

# %%
emp_measure = "emp_rtl"

# %run employment_analysis.ipynb
# Out:
# **********************************************************************************
# Raw Regression Employment Growth on Tariffs
#
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:      employment_growth   R-squared:                        0.0022
# Estimator:                   PanelOLS   R-squared (Between):             -0.0026
# No. Observations:               55053   R-squared (Within):               0.0069
# Date:                Tue, Dec 17 2019   R-squared (Overall):              0.0022
# Time:                        08:27:30   Log-likelihood                 1.066e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1292.3
# Entities:                        3082   P-value                           0.0000
# Avg Obs:                       17.863   Distribution:                 F(1,55051)
# Min Obs:                       3.0000
# ...

# %% [markdown]
# ---
#
# ## Pretrend Figures for Autos, Figure 4
# <a id='pretrend_autos'></a>

# %%
# %run pretrends_autos.ipynb
# Out:
# ERROR:root:File `'pretrends_autos.ipynb.py'` not found.

# %% [markdown]
# ---
#
# ## Pretrend Figures for Employment, Figures 5a - 5c
# <a id='pretrend_emp'></a>

# %% [markdown]
# ### Total Employment Figure 5a

# %%
emp_measure = "emp_all"

# %run pretrend_notebook.ipynb
# Out:
# (97560, 1)
# (97560,)

# %% [markdown]
# ### Goods-Producing Employment Figure 5b

# %%
emp_measure = "emp_gds"

# %run pretrend_notebook.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\github\consumption_and_tradewar\pretrend_notebook.ipynb in <module>()
#       3 fig_path = file_path +"\\figures"
#       4
# ----> 5 trade_county = pq.read_table(file_path + "\\data\\trade_employment_blssingle19.parquet").to_pandas()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyarrow\parquet.py in read_table(source, columns, use_threads, metadata, use_pandas_metadata, memory_map, filesystem)
#    1150         return fs.read_parquet(path, columns=columns,
#    1151                                use_threads=use_threads, metadata=metadata,
# -> 1152                                use_pandas_metadata=use_pandas_metadata)
#    1153
#    1154     pf = ParquetFile(source, metadata=metadata)
#
# ...

# %% [markdown]
# ### Retail Employment Figure 5c

# %%
emp_measure = "emp_rtl"

# %run pretrend_notebook.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\github\consumption_and_tradewar\pretrend_notebook.ipynb in <module>()
#       3 fig_path = file_path +"\\figures"
#       4
# ----> 5 trade_county = pq.read_table(file_path + "\\data\\trade_employment_blssingle19.parquet").to_pandas()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyarrow\parquet.py in read_table(source, columns, use_threads, metadata, use_pandas_metadata, memory_map, filesystem)
#    1150         return fs.read_parquet(path, columns=columns,
#    1151                                use_threads=use_threads, metadata=metadata,
# -> 1152                                use_pandas_metadata=use_pandas_metadata)
#    1153
#    1154     pf = ParquetFile(source, metadata=metadata)
#
# ...

# %% [markdown]
# ---
#
# ## Mapping
# <a id='mapping'></a>

# %%
# %run tariff_map.ipynb
# Out:
# WARNING:Fiona:GDAL data files not located, GDAL_DATA not set
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# **********************************************************************************
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\github\consumption_and_tradewar\tariff_map.ipynb in <module>()
#       5 fig_path = file_path +"\\figures"
#       6
# ----> 7 trade_data = pq.read_table(file_path + "\\data\\total_trade_data_2015.parquet").to_pandas()
#       8
#       9 trade_data["time"] = pd.to_datetime(trade_data.time)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyarrow\parquet.py in read_table(source, columns, use_threads, metadata, use_pandas_metadata, memory_map, filesystem)
#    1150         return fs.read_parquet(path, columns=columns,
#    1151                                use_threads=use_threads, metadata=metadata,
# ...
